# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# now let get all the information for stock
stock =  read_csv('BABA20130425_20180425.csv', header=0)
print(stock.shape)
print(stock.head())
# Out:
# (905, 7)
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2014-09-19  92.699997  99.699997  89.949997  93.889999  93.889999
# 1  2014-09-22  92.699997  92.949997  89.500000  89.889999  89.889999
# 2  2014-09-23  88.940002  90.480003  86.620003  87.169998  87.169998
# 3  2014-09-24  88.470001  90.570000  87.220001  90.570000  90.570000
# 4  2014-09-25  91.089996  91.500000  88.500000  88.919998  88.919998
#
#       Volume
# 0  271879400
# 1   66657800
# 2   39009800
# 3   32088000
# 4   28598000

# %%
# now get the stock close price
# astype means "Copy of the array, cast to a specified type."
stock_prices = stock.Close.values.astype("float32")
shape0=stock_prices.shape[0]
stock_prices = stock_prices.reshape(shape0, 1)
print(stock_prices.shape)
# print the prices of last five observations
print(stock_prices[-5:])
# Out:
# (905, 1)
# [[ 182.67999268]
#  [ 181.38999939]
#  [ 179.11000061]
#  [ 175.57000732]
#  [ 173.08999634]]

# %%
# Before doing any analysis, first plot the prices series(data)
pyplot.plot(stock_prices)
pyplot.title('Stock close price over time')
pyplot.ylabel('Price')
pyplot.xlabel('Time Range')
pyplot.show()

# %%
# now get the stock Volume
# astype means "Copy of the array, cast to a specified type."
stock_volumes = stock.Volume.values.astype("float32")
shape0=stock_volumes.shape[0]
stock_volumes = stock_volumes.reshape(shape0, 1)
print(stock_volumes.shape)
# print the volumes of last five observations
print(stock_volumes[-5:])
# Out:
# (905, 1)
# [[ 16972700.]
#  [ 11989000.]
#  [ 14473100.]
#  [ 12033900.]
#  [ 14340100.]]

# %%
# Before doing any analysis, first plot the volumes series(data)
pyplot.plot(stock_volumes)
pyplot.title('Stock trading volumes over time')
pyplot.ylabel('Volumes')
pyplot.xlabel('Time Range')
pyplot.show()

# %%
values = concatenate((stock_prices, stock_volumes), axis=1)

# %%
# check the last five observations to make sure it's correct
print(values[-5:, :])
# Out:
# [[  1.82679993e+02   1.69727000e+07]
#  [  1.81389999e+02   1.19890000e+07]
#  [  1.79110001e+02   1.44731000e+07]
#  [  1.75570007e+02   1.20339000e+07]
#  [  1.73089996e+02   1.43401000e+07]]

# %%
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
print(reframed.head())
# var1 means prices, var2 means volumns
# Out:
#    var1(t-1)  var2(t-1)   var1(t)   var2(t)
# 1   0.246905   1.000000  0.219847  0.234545
# 2   0.219847   0.234545  0.201448  0.131421
# 3   0.201448   0.131421  0.224447  0.105603
# 4   0.224447   0.105603  0.213286  0.092586
# 5   0.213286   0.092586  0.223703  0.054325

# %%
# drop columns we don't want to predict
reframed.drop(reframed.columns[[3]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)   var1(t)
# 1   0.246905   1.000000  0.219847
# 2   0.219847   0.234545  0.201448
# 3   0.201448   0.131421  0.224447
# 4   0.224447   0.105603  0.213286
# 5   0.213286   0.092586  0.223703

# %%
# split into train and test sets
values = reframed.values
n_train = int(reframed.shape[0] * 0.8)
train = values[:n_train, :]
test = values[n_train:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (723, 1, 2) (723,) (181, 1, 2) (181,)

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]),return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(100, return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(1))
model.add(Activation('linear'))

model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=300, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 723 samples, validate on 181 samples
# Epoch 1/300
# 0s - loss: 0.2148 - val_loss: 0.7558
# Epoch 2/300
# 0s - loss: 0.1540 - val_loss: 0.6524
# Epoch 3/300
# 0s - loss: 0.0959 - val_loss: 0.5350
# Epoch 4/300
# 0s - loss: 0.0877 - val_loss: 0.4749
# Epoch 5/300
# 0s - loss: 0.0906 - val_loss: 0.4564
# Epoch 6/300
# 0s - loss: 0.0888 - val_loss: 0.4501
# Epoch 7/300
# 0s - loss: 0.0838 - val_loss: 0.4400
# Epoch 8/300
# 0s - loss: 0.0799 - val_loss: 0.4227
# Epoch 9/300
# 0s - loss: 0.0762 - val_loss: 0.3965
# Epoch 10/300
# 0s - loss: 0.0713 - val_loss: 0.3664
# Epoch 11/300
# 0s - loss: 0.0677 - val_loss: 0.3336
# Epoch 12/300
# 0s - loss: 0.0645 - val_loss: 0.3010
# Epoch 13/300
# 0s - loss: 0.0579 - val_loss: 0.2604
# Epoch 14/300
# 0s - loss: 0.0520 - val_loss: 0.2124
# Epoch 15/300
# 0s - loss: 0.0460 - val_loss: 0.1633
# Epoch 16/300
# 0s - loss: 0.0388 - val_loss: 0.1107
# Epoch 17/300
# 0s - loss: 0.0304 - val_loss: 0.0512
# Epoch 18/300
# 0s - loss: 0.0255 - val_loss: 0.0224
# Epoch 19/300
# 0s - loss: 0.0216 - val_loss: 0.0357
# Epoch 20/300
# 0s - loss: 0.0204 - val_loss: 0.0453
# Epoch 21/300
# 0s - loss: 0.0209 - val_loss: 0.0612
# Epoch 22/300
# 0s - loss: 0.0205 - val_loss: 0.0427
# Epoch 23/300
# 0s - loss: 0.0195 - val_loss: 0.0683
# Epoch 24/300
# 0s - loss: 0.0197 - val_loss: 0.0705
# Epoch 25/300
# 0s - loss: 0.0201 - val_loss: 0.0457
# Epoch 26/300
# 0s - loss: 0.0213 - val_loss: 0.0245
# Epoch 27/300
# 0s - loss: 0.0195 - val_loss: 0.0302
# Epoch 28/300
# 0s - loss: 0.0198 - val_loss: 0.0310
# Epoch 29/300
# 0s - loss: 0.0212 - val_loss: 0.0307
# Epoch 30/300
# 0s - loss: 0.0188 - val_loss: 0.0613
# Epoch 31/300
# 0s - loss: 0.0197 - val_loss: 0.0546
# Epoch 32/300
# 0s - loss: 0.0187 - val_loss: 0.0760
# Epoch 33/300
# 0s - loss: 0.0179 - val_loss: 0.0502
# Epoch 34/300
# 0s - loss: 0.0185 - val_loss: 0.0374
# Epoch 35/300
# 0s - loss: 0.0194 - val_loss: 0.0476
# Epoch 36/300
# 0s - loss: 0.0181 - val_loss: 0.0534
# Epoch 37/300
# 0s - loss: 0.0214 - val_loss: 0.0560
# Epoch 38/300
# 0s - loss: 0.0207 - val_loss: 0.0221
# Epoch 39/300
# 0s - loss: 0.0196 - val_loss: 0.0246
# Epoch 40/300
# 0s - loss: 0.0189 - val_loss: 0.0359
# Epoch 41/300
# 0s - loss: 0.0201 - val_loss: 0.0331
# Epoch 42/300
# 0s - loss: 0.0191 - val_loss: 0.0611
# Epoch 43/300
# 0s - loss: 0.0204 - val_loss: 0.0283
# Epoch 44/300
# 0s - loss: 0.0171 - val_loss: 0.0550
# Epoch 45/300
# 0s - loss: 0.0171 - val_loss: 0.0543
# Epoch 46/300
# 0s - loss: 0.0165 - val_loss: 0.0484
# Epoch 47/300
# 0s - loss: 0.0168 - val_loss: 0.0342
# Epoch 48/300
# 0s - loss: 0.0173 - val_loss: 0.0424
# Epoch 49/300
# 0s - loss: 0.0165 - val_loss: 0.0520
# Epoch 50/300
# 0s - loss: 0.0187 - val_loss: 0.0410
# Epoch 51/300
# 0s - loss: 0.0199 - val_loss: 0.0228
# Epoch 52/300
# 0s - loss: 0.0202 - val_loss: 0.0242
# Epoch 53/300
# 0s - loss: 0.0178 - val_loss: 0.0421
# Epoch 54/300
# 0s - loss: 0.0184 - val_loss: 0.0256
# Epoch 55/300
# 0s - loss: 0.0166 - val_loss: 0.0403
# Epoch 56/300
# 0s - loss: 0.0179 - val_loss: 0.0254
# Epoch 57/300
# 0s - loss: 0.0191 - val_loss: 0.0260
# Epoch 58/300
# 0s - loss: 0.0192 - val_loss: 0.0218
# Epoch 59/300
# 0s - loss: 0.0167 - val_loss: 0.0400
# Epoch 60/300
# 0s - loss: 0.0154 - val_loss: 0.0576
# Epoch 61/300
# 0s - loss: 0.0152 - val_loss: 0.0441
# Epoch 62/300
# 0s - loss: 0.0175 - val_loss: 0.0226
# Epoch 63/300
# 0s - loss: 0.0182 - val_loss: 0.0267
# Epoch 64/300
# 0s - loss: 0.0162 - val_loss: 0.0410
# Epoch 65/300
# 0s - loss: 0.0166 - val_loss: 0.0456
# Epoch 66/300
# 0s - loss: 0.0174 - val_loss: 0.0216
# Epoch 67/300
# 0s - loss: 0.0168 - val_loss: 0.0235
# Epoch 68/300
# 0s - loss: 0.0168 - val_loss: 0.0236
# Epoch 69/300
# 0s - loss: 0.0160 - val_loss: 0.0297
# Epoch 70/300
# 0s - loss: 0.0168 - val_loss: 0.0267
# Epoch 71/300
# 0s - loss: 0.0156 - val_loss: 0.0436
# Epoch 72/300
# 0s - loss: 0.0171 - val_loss: 0.0320
# Epoch 73/300
# 0s - loss: 0.0152 - val_loss: 0.0370
# Epoch 74/300
# 0s - loss: 0.0159 - val_loss: 0.0289
# Epoch 75/300
# 0s - loss: 0.0160 - val_loss: 0.0219
# Epoch 76/300
# 0s - loss: 0.0192 - val_loss: 0.0330
# Epoch 77/300
# 0s - loss: 0.0187 - val_loss: 0.0206
# Epoch 78/300
# 0s - loss: 0.0150 - val_loss: 0.0282
# Epoch 79/300
# 0s - loss: 0.0164 - val_loss: 0.0409
# Epoch 80/300
# 0s - loss: 0.0224 - val_loss: 0.0223
# Epoch 81/300
# 0s - loss: 0.0186 - val_loss: 0.0425
# Epoch 82/300
# 0s - loss: 0.0183 - val_loss: 0.0242
# Epoch 83/300
# 0s - loss: 0.0176 - val_loss: 0.0207
# Epoch 84/300
# 0s - loss: 0.0144 - val_loss: 0.0336
# Epoch 85/300
# 0s - loss: 0.0145 - val_loss: 0.0340
# Epoch 86/300
# 0s - loss: 0.0147 - val_loss: 0.0359
# Epoch 87/300
# 0s - loss: 0.0160 - val_loss: 0.0474
# Epoch 88/300
# 0s - loss: 0.0171 - val_loss: 0.0372
# Epoch 89/300
# 0s - loss: 0.0168 - val_loss: 0.0266
# Epoch 90/300
# 0s - loss: 0.0194 - val_loss: 0.0317
# Epoch 91/300
# 0s - loss: 0.0177 - val_loss: 0.0217
# Epoch 92/300
# 0s - loss: 0.0158 - val_loss: 0.0306
# Epoch 93/300
# 0s - loss: 0.0152 - val_loss: 0.0201
# Epoch 94/300
# 0s - loss: 0.0206 - val_loss: 0.0207
# Epoch 95/300
# 0s - loss: 0.0174 - val_loss: 0.0351
# Epoch 96/300
# 0s - loss: 0.0164 - val_loss: 0.0204
# Epoch 97/300
# 0s - loss: 0.0167 - val_loss: 0.0248
# Epoch 98/300
# 0s - loss: 0.0175 - val_loss: 0.0351
# Epoch 99/300
# 0s - loss: 0.0191 - val_loss: 0.0282
# Epoch 100/300
# 0s - loss: 0.0149 - val_loss: 0.0217
# Epoch 101/300
# 0s - loss: 0.0186 - val_loss: 0.0211
# Epoch 102/300
# 0s - loss: 0.0156 - val_loss: 0.0357
# Epoch 103/300
# 0s - loss: 0.0167 - val_loss: 0.0475
# Epoch 104/300
# 0s - loss: 0.0179 - val_loss: 0.0210
# Epoch 105/300
# 0s - loss: 0.0157 - val_loss: 0.0282
# Epoch 106/300
# 0s - loss: 0.0151 - val_loss: 0.0208
# Epoch 107/300
# 0s - loss: 0.0189 - val_loss: 0.0287
# Epoch 108/300
# 0s - loss: 0.0168 - val_loss: 0.0222
# Epoch 109/300
# 0s - loss: 0.0157 - val_loss: 0.0373
# Epoch 110/300
# 0s - loss: 0.0159 - val_loss: 0.0201
# Epoch 111/300
# 0s - loss: 0.0151 - val_loss: 0.0204
# Epoch 112/300
# 0s - loss: 0.0151 - val_loss: 0.0223
# Epoch 113/300
# 0s - loss: 0.0156 - val_loss: 0.0210
# Epoch 114/300
# 0s - loss: 0.0152 - val_loss: 0.0199
# Epoch 115/300
# 0s - loss: 0.0144 - val_loss: 0.0277
# Epoch 116/300
# 0s - loss: 0.0151 - val_loss: 0.0297
# Epoch 117/300
# 0s - loss: 0.0154 - val_loss: 0.0258
# Epoch 118/300
# 0s - loss: 0.0153 - val_loss: 0.0199
# Epoch 119/300
# 0s - loss: 0.0146 - val_loss: 0.0217
# Epoch 120/300
# 0s - loss: 0.0140 - val_loss: 0.0267
# Epoch 121/300
# 0s - loss: 0.0151 - val_loss: 0.0199
# Epoch 122/300
# 0s - loss: 0.0196 - val_loss: 0.0374
# Epoch 123/300
# 0s - loss: 0.0154 - val_loss: 0.0211
# Epoch 124/300
# 0s - loss: 0.0144 - val_loss: 0.0386
# Epoch 125/300
# 0s - loss: 0.0165 - val_loss: 0.0291
# Epoch 126/300
# 0s - loss: 0.0156 - val_loss: 0.0253
# Epoch 127/300
# 0s - loss: 0.0199 - val_loss: 0.0256
# Epoch 128/300
# 0s - loss: 0.0150 - val_loss: 0.0273
# Epoch 129/300
# 0s - loss: 0.0165 - val_loss: 0.0224
# Epoch 130/300
# 0s - loss: 0.0182 - val_loss: 0.0336
# Epoch 131/300
# 0s - loss: 0.0185 - val_loss: 0.0211
# Epoch 132/300
# 0s - loss: 0.0167 - val_loss: 0.0251
# Epoch 133/300
# 0s - loss: 0.0159 - val_loss: 0.0226
# Epoch 134/300
# 0s - loss: 0.0145 - val_loss: 0.0206
# Epoch 135/300
# 0s - loss: 0.0143 - val_loss: 0.0208
# Epoch 136/300
# 0s - loss: 0.0138 - val_loss: 0.0227
# Epoch 137/300
# 0s - loss: 0.0151 - val_loss: 0.0218
# Epoch 138/300
# 0s - loss: 0.0147 - val_loss: 0.0365
# Epoch 139/300
# 0s - loss: 0.0147 - val_loss: 0.0242
# Epoch 140/300
# 0s - loss: 0.0148 - val_loss: 0.0196
# Epoch 141/300
# 0s - loss: 0.0175 - val_loss: 0.0329
# Epoch 142/300
# 0s - loss: 0.0149 - val_loss: 0.0205
# Epoch 143/300
# 0s - loss: 0.0148 - val_loss: 0.0255
# Epoch 144/300
# 0s - loss: 0.0152 - val_loss: 0.0198
# Epoch 145/300
# 0s - loss: 0.0147 - val_loss: 0.0197
# Epoch 146/300
# 0s - loss: 0.0140 - val_loss: 0.0301
# Epoch 147/300
# 0s - loss: 0.0156 - val_loss: 0.0301
# Epoch 148/300
# 0s - loss: 0.0158 - val_loss: 0.0199
# Epoch 149/300
# 0s - loss: 0.0197 - val_loss: 0.0293
# Epoch 150/300
# 0s - loss: 0.0146 - val_loss: 0.0305
# Epoch 151/300
# 0s - loss: 0.0158 - val_loss: 0.0372
# Epoch 152/300
# 0s - loss: 0.0144 - val_loss: 0.0225
# Epoch 153/300
# 0s - loss: 0.0163 - val_loss: 0.0197
# Epoch 154/300
# 0s - loss: 0.0154 - val_loss: 0.0267
# Epoch 155/300
# 0s - loss: 0.0162 - val_loss: 0.0240
# Epoch 156/300
# 0s - loss: 0.0195 - val_loss: 0.0354
# Epoch 157/300
# 0s - loss: 0.0160 - val_loss: 0.0263
# Epoch 158/300
# 0s - loss: 0.0209 - val_loss: 0.0600
# Epoch 159/300
# 0s - loss: 0.0171 - val_loss: 0.0218
# Epoch 160/300
# 0s - loss: 0.0142 - val_loss: 0.0205
# Epoch 161/300
# 0s - loss: 0.0141 - val_loss: 0.0195
# Epoch 162/300
# 0s - loss: 0.0142 - val_loss: 0.0201
# Epoch 163/300
# 0s - loss: 0.0141 - val_loss: 0.0316
# Epoch 164/300
# 0s - loss: 0.0139 - val_loss: 0.0195
# Epoch 165/300
# 0s - loss: 0.0145 - val_loss: 0.0203
# Epoch 166/300
# 0s - loss: 0.0150 - val_loss: 0.0197
# Epoch 167/300
# 0s - loss: 0.0141 - val_loss: 0.0199
# Epoch 168/300
# 0s - loss: 0.0142 - val_loss: 0.0232
# Epoch 169/300
# 0s - loss: 0.0155 - val_loss: 0.0258
# Epoch 170/300
# 0s - loss: 0.0146 - val_loss: 0.0203
# Epoch 171/300
# 0s - loss: 0.0162 - val_loss: 0.0275
# Epoch 172/300
# 0s - loss: 0.0156 - val_loss: 0.0220
# Epoch 173/300
# 0s - loss: 0.0156 - val_loss: 0.0199
# Epoch 174/300
# 0s - loss: 0.0137 - val_loss: 0.0261
# Epoch 175/300
# 0s - loss: 0.0153 - val_loss: 0.0236
# Epoch 176/300
# 0s - loss: 0.0140 - val_loss: 0.0192
# Epoch 177/300
# 0s - loss: 0.0174 - val_loss: 0.0244
# Epoch 178/300
# 0s - loss: 0.0137 - val_loss: 0.0192
# Epoch 179/300
# 0s - loss: 0.0153 - val_loss: 0.0199
# Epoch 180/300
# 0s - loss: 0.0139 - val_loss: 0.0211
# Epoch 181/300
# 0s - loss: 0.0141 - val_loss: 0.0226
# Epoch 182/300
# 0s - loss: 0.0167 - val_loss: 0.0450
# Epoch 183/300
# 0s - loss: 0.0160 - val_loss: 0.0360
# Epoch 184/300
# 0s - loss: 0.0137 - val_loss: 0.0202
# Epoch 185/300
# 0s - loss: 0.0128 - val_loss: 0.0202
# Epoch 186/300
# 0s - loss: 0.0157 - val_loss: 0.0375
# Epoch 187/300
# 0s - loss: 0.0179 - val_loss: 0.0457
# Epoch 188/300
# 0s - loss: 0.0157 - val_loss: 0.0329
# Epoch 189/300
# 0s - loss: 0.0218 - val_loss: 0.0604
# Epoch 190/300
# 0s - loss: 0.0156 - val_loss: 0.0193
# Epoch 191/300
# 0s - loss: 0.0139 - val_loss: 0.0191
# Epoch 192/300
# 0s - loss: 0.0140 - val_loss: 0.0212
# Epoch 193/300
# 0s - loss: 0.0157 - val_loss: 0.0196
# Epoch 194/300
# 0s - loss: 0.0174 - val_loss: 0.0238
# Epoch 195/300
# 0s - loss: 0.0140 - val_loss: 0.0256
# Epoch 196/300
# 0s - loss: 0.0147 - val_loss: 0.0270
# Epoch 197/300
# 0s - loss: 0.0134 - val_loss: 0.0207
# Epoch 198/300
# 0s - loss: 0.0140 - val_loss: 0.0202
# Epoch 199/300
# 0s - loss: 0.0136 - val_loss: 0.0203
# Epoch 200/300
# 0s - loss: 0.0147 - val_loss: 0.0221
# Epoch 201/300
# 0s - loss: 0.0136 - val_loss: 0.0192
# Epoch 202/300
# 0s - loss: 0.0140 - val_loss: 0.0241
# Epoch 203/300
# 0s - loss: 0.0152 - val_loss: 0.0223
# Epoch 204/300
# 0s - loss: 0.0131 - val_loss: 0.0197
# Epoch 205/300
# 0s - loss: 0.0143 - val_loss: 0.0194
# Epoch 206/300
# 0s - loss: 0.0142 - val_loss: 0.0230
# Epoch 207/300
# 0s - loss: 0.0137 - val_loss: 0.0216
# Epoch 208/300
# 0s - loss: 0.0130 - val_loss: 0.0212
# Epoch 209/300
# 0s - loss: 0.0134 - val_loss: 0.0226
# Epoch 210/300
# 0s - loss: 0.0133 - val_loss: 0.0266
# Epoch 211/300
# 0s - loss: 0.0142 - val_loss: 0.0274
# Epoch 212/300
# 0s - loss: 0.0155 - val_loss: 0.0206
# Epoch 213/300
# 0s - loss: 0.0159 - val_loss: 0.0338
# Epoch 214/300
# 0s - loss: 0.0180 - val_loss: 0.0214
# Epoch 215/300
# 0s - loss: 0.0165 - val_loss: 0.0440
# Epoch 216/300
# 0s - loss: 0.0162 - val_loss: 0.0413
# Epoch 217/300
# 0s - loss: 0.0137 - val_loss: 0.0217
# Epoch 218/300
# 0s - loss: 0.0124 - val_loss: 0.0207
# Epoch 219/300
# 0s - loss: 0.0139 - val_loss: 0.0228
# Epoch 220/300
# 0s - loss: 0.0152 - val_loss: 0.0199
# Epoch 221/300
# 0s - loss: 0.0151 - val_loss: 0.0285
# Epoch 222/300
# 0s - loss: 0.0136 - val_loss: 0.0192
# Epoch 223/300
# 0s - loss: 0.0137 - val_loss: 0.0285
# Epoch 224/300
# 0s - loss: 0.0148 - val_loss: 0.0353
# Epoch 225/300
# 0s - loss: 0.0148 - val_loss: 0.0210
# Epoch 226/300
# 0s - loss: 0.0142 - val_loss: 0.0214
# Epoch 227/300
# 0s - loss: 0.0172 - val_loss: 0.0193
# Epoch 228/300
# 0s - loss: 0.0191 - val_loss: 0.0337
# Epoch 229/300
# 0s - loss: 0.0142 - val_loss: 0.0196
# Epoch 230/300
# 0s - loss: 0.0177 - val_loss: 0.0202
# Epoch 231/300
# 0s - loss: 0.0192 - val_loss: 0.0556
# Epoch 232/300
# 0s - loss: 0.0139 - val_loss: 0.0225
# Epoch 233/300
# 0s - loss: 0.0139 - val_loss: 0.0193
# Epoch 234/300
# 0s - loss: 0.0135 - val_loss: 0.0245
# Epoch 235/300
# 0s - loss: 0.0150 - val_loss: 0.0421
# Epoch 236/300
# 0s - loss: 0.0140 - val_loss: 0.0304
# Epoch 237/300
# 0s - loss: 0.0136 - val_loss: 0.0193
# Epoch 238/300
# 0s - loss: 0.0141 - val_loss: 0.0209
# Epoch 239/300
# 0s - loss: 0.0141 - val_loss: 0.0276
# Epoch 240/300
# 0s - loss: 0.0190 - val_loss: 0.0373
# Epoch 241/300
# 0s - loss: 0.0142 - val_loss: 0.0243
# Epoch 242/300
# 0s - loss: 0.0148 - val_loss: 0.0247
# Epoch 243/300
# 0s - loss: 0.0134 - val_loss: 0.0202
# Epoch 244/300
# 0s - loss: 0.0132 - val_loss: 0.0245
# Epoch 245/300
# 0s - loss: 0.0149 - val_loss: 0.0217
# Epoch 246/300
# 0s - loss: 0.0134 - val_loss: 0.0197
# Epoch 247/300
# 0s - loss: 0.0143 - val_loss: 0.0193
# Epoch 248/300
# 0s - loss: 0.0147 - val_loss: 0.0219
# Epoch 249/300
# 0s - loss: 0.0127 - val_loss: 0.0201
# Epoch 250/300
# 0s - loss: 0.0132 - val_loss: 0.0219
# Epoch 251/300
# 0s - loss: 0.0126 - val_loss: 0.0194
# Epoch 252/300
# 0s - loss: 0.0133 - val_loss: 0.0194
# Epoch 253/300
# 0s - loss: 0.0139 - val_loss: 0.0228
# Epoch 254/300
# 0s - loss: 0.0150 - val_loss: 0.0492
# Epoch 255/300
# 0s - loss: 0.0204 - val_loss: 0.0544
# Epoch 256/300
# 0s - loss: 0.0142 - val_loss: 0.0198
# Epoch 257/300
# 0s - loss: 0.0151 - val_loss: 0.0215
# Epoch 258/300
# 0s - loss: 0.0143 - val_loss: 0.0280
# Epoch 259/300
# 0s - loss: 0.0214 - val_loss: 0.0519
# Epoch 260/300
# 0s - loss: 0.0147 - val_loss: 0.0191
# Epoch 261/300
# 0s - loss: 0.0137 - val_loss: 0.0192
# Epoch 262/300
# 0s - loss: 0.0137 - val_loss: 0.0204
# Epoch 263/300
# 0s - loss: 0.0137 - val_loss: 0.0236
# Epoch 264/300
# 0s - loss: 0.0153 - val_loss: 0.0197
# Epoch 265/300
# 0s - loss: 0.0166 - val_loss: 0.0413
# Epoch 266/300
# 0s - loss: 0.0157 - val_loss: 0.0217
# Epoch 267/300
# 0s - loss: 0.0156 - val_loss: 0.0193
# Epoch 268/300
# 0s - loss: 0.0151 - val_loss: 0.0240
# Epoch 269/300
# 0s - loss: 0.0130 - val_loss: 0.0192
# Epoch 270/300
# 0s - loss: 0.0126 - val_loss: 0.0239
# Epoch 271/300
# 0s - loss: 0.0151 - val_loss: 0.0342
# Epoch 272/300
# 0s - loss: 0.0133 - val_loss: 0.0227
# Epoch 273/300
# 0s - loss: 0.0133 - val_loss: 0.0210
# Epoch 274/300
# 0s - loss: 0.0135 - val_loss: 0.0317
# Epoch 275/300
# 0s - loss: 0.0137 - val_loss: 0.0289
# Epoch 276/300
# 0s - loss: 0.0132 - val_loss: 0.0226
# Epoch 277/300
# 0s - loss: 0.0138 - val_loss: 0.0324
# Epoch 278/300
# 0s - loss: 0.0180 - val_loss: 0.0572
# Epoch 279/300
# 0s - loss: 0.0137 - val_loss: 0.0252
# Epoch 280/300
# 0s - loss: 0.0132 - val_loss: 0.0195
# Epoch 281/300
# 0s - loss: 0.0141 - val_loss: 0.0218
# Epoch 282/300
# 0s - loss: 0.0124 - val_loss: 0.0239
# Epoch 283/300
# 0s - loss: 0.0133 - val_loss: 0.0199
# Epoch 284/300
# 0s - loss: 0.0135 - val_loss: 0.0191
# Epoch 285/300
# 0s - loss: 0.0137 - val_loss: 0.0190
# Epoch 286/300
# 0s - loss: 0.0131 - val_loss: 0.0261
# Epoch 287/300
# 0s - loss: 0.0146 - val_loss: 0.0249
# Epoch 288/300
# 0s - loss: 0.0144 - val_loss: 0.0259
# Epoch 289/300
# 0s - loss: 0.0157 - val_loss: 0.0192
# Epoch 290/300
# 0s - loss: 0.0160 - val_loss: 0.0417
# Epoch 291/300
# 0s - loss: 0.0153 - val_loss: 0.0304
# Epoch 292/300
# 0s - loss: 0.0143 - val_loss: 0.0195
# Epoch 293/300
# 0s - loss: 0.0170 - val_loss: 0.0212
# Epoch 294/300
# 0s - loss: 0.0183 - val_loss: 0.0518
# Epoch 295/300
# 0s - loss: 0.0158 - val_loss: 0.0214
# Epoch 296/300
# 0s - loss: 0.0170 - val_loss: 0.0220
# Epoch 297/300
# 0s - loss: 0.0192 - val_loss: 0.0442
# Epoch 298/300
# 0s - loss: 0.0139 - val_loss: 0.0204
# Epoch 299/300
# 0s - loss: 0.0145 - val_loss: 0.0223
# Epoch 300/300
# 0s - loss: 0.0133 - val_loss: 0.0206

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
# make a prediction for train data
yhat_train = model.predict(train_X)
train_X = train_X.reshape((train_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat_train = concatenate((yhat_train, train_X[:, 1:]), axis=1)
inv_yhat_train = scaler.inverse_transform(inv_yhat_train)
inv_yhat_train = inv_yhat_train[:,0]
# invert scaling for actual
train_y = train_y.reshape((len(train_y), 1))
inv_y_train = concatenate((train_y, train_X[:, 1:]), axis=1)
inv_y_train = scaler.inverse_transform(inv_y_train)
inv_y_train = inv_y_train[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y_train, inv_yhat_train))
print('Train RMSE: %.3f' % rmse)
# Out:
# Train RMSE: 1.809

# %%
# plot only the train data and predicted train data
trainline, =pyplot.plot(inv_y_train, label='train data')  # blue one
trainPredictline, =pyplot.plot(inv_yhat_train, label='predicted train data') # orange one
pyplot.title("Train data perormance")
pyplot.ylabel('Stock price')
pyplot.xlabel('Time range')
pyplot.legend(handles=[trainline, trainPredictline])
pyplot.show()

# %%
# plot only the last 100 train data and predicted train data
trainline, =pyplot.plot(inv_y_train[-30:], label='train data')  # blue one
trainPredictline, =pyplot.plot(inv_yhat_train[-30:], label='predicted train data') # orange one
pyplot.title("Train data perormance over recent 30 observations")
pyplot.ylabel('Stock price')
pyplot.xlabel('Time range')
pyplot.legend(handles=[trainline, trainPredictline])
pyplot.show()

# %%
# check some observations of train data
print(inv_y_train.shape)
print(inv_yhat_train.shape)
# check the performance
print(inv_y_train[-1])
print(inv_yhat_train[-1])
#
print(inv_y_train[-2])
print(inv_yhat_train[-2])
#
print(inv_y_train[-3])
print(inv_yhat_train[-3])
#
print(inv_y_train[-4])
print(inv_yhat_train[-4])
# Out:
# (723,)
# (723,)
# 153.32
# 151.705
# 151.91
# 154.398
# 154.73
# 154.657
# 154.95
# 157.169

# %%
# plot the difference for train data
traindiff = inv_yhat_train - inv_y_train
#
maxtraindiff=abs(max(traindiff, key=abs))
print('The largest absolute difference for train data: %.2f' % (maxtraindiff))
#
pyplot.plot(traindiff)
#
pyplot.title("Predicted train data minus train data")
pyplot.ylabel('Difference')
pyplot.xlabel('Time range')
pyplot.show()
# Out:
# The largest absolute difference for train data: 16.60

# %%
# plot the difference for the recent 30 obs of train data
pyplot.plot(traindiff[-30:])
#
pyplot.title("Predicted train data minus train data over recent 30 observations")
pyplot.ylabel('Difference')
pyplot.xlabel('Time range')
pyplot.show()

# %%
# make a prediction for test data
yhat_test = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat_test = concatenate((yhat_test, test_X[:, 1:]), axis=1)
inv_yhat_test = scaler.inverse_transform(inv_yhat_test)
inv_yhat_test = inv_yhat_test[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y_test = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y_test = scaler.inverse_transform(inv_y_test)
inv_y_test = inv_y_test[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y_test, inv_yhat_test))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 3.846

# %%
# plot only the test data and predicted test data
testline, =pyplot.plot(inv_y_test, label='test data')  # blue one
testPredictline, =pyplot.plot(inv_yhat_test, label='predicted test data') # orange one
pyplot.title("Test data perormance")
pyplot.ylabel('Stock price')
pyplot.xlabel('Time range')
pyplot.legend(handles=[testline, testPredictline])
pyplot.show()

# %%
# plot only the last 30 test data and predicted test data
testline, =pyplot.plot(inv_y_test[-30:], label='test data')  # blue one
testPredictline, =pyplot.plot(inv_yhat_test[-30:], label='predicted test data') # orange one
pyplot.title("Test data perormance over recent 30 observations")
pyplot.ylabel('Stock price')
pyplot.xlabel('Time range')
pyplot.legend(handles=[testline, testPredictline])
pyplot.show()

# %%
# check some observations of test data
print(inv_y_test.shape)
print(inv_yhat_test.shape)
# check the performance
print(inv_y_test[-1])
print(inv_yhat_test[-1])
#
print(inv_y_test[-2])
print(inv_yhat_test[-2])
#
print(inv_y_test[-3])
print(inv_yhat_test[-3])
#
print(inv_y_test[-4])
print(inv_yhat_test[-4])
# Out:
# (181,)
# (181,)
# 173.09
# 174.475
# 175.57
# 177.864
# 179.11
# 179.998
# 181.39
# 181.268

# %%
# plot the difference for test data
testdiff = inv_yhat_test - inv_y_test
#
maxtestdiff=abs(max(testdiff, key=abs))
print('The largest absolute difference for test data: %.2f' % (maxtestdiff))
#
pyplot.plot(testdiff)
#
pyplot.title("Predicted test data minus test data")
pyplot.ylabel('Difference')
pyplot.xlabel('Time range')
pyplot.show()
# Out:
# The largest absolute difference for test data: 12.19

# %%
# plot the difference for the recent 30 obs of test data
pyplot.plot(testdiff[-30:])
#
pyplot.title("Predicted test data minus test data over recent 30 observations")
pyplot.ylabel('Difference')
pyplot.xlabel('Time range')
pyplot.show()

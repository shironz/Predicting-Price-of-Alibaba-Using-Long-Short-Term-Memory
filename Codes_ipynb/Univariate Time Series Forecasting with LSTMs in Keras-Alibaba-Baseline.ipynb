# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# now let get all the information for stock
stock =  read_csv('BABA20130425_20180425.csv', header=0)
print(stock.shape)
print(stock.head())
# Out:
# (905, 7)
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2014-09-19  92.699997  99.699997  89.949997  93.889999  93.889999
# 1  2014-09-22  92.699997  92.949997  89.500000  89.889999  89.889999
# 2  2014-09-23  88.940002  90.480003  86.620003  87.169998  87.169998
# 3  2014-09-24  88.470001  90.570000  87.220001  90.570000  90.570000
# 4  2014-09-25  91.089996  91.500000  88.500000  88.919998  88.919998
#
#       Volume
# 0  271879400
# 1   66657800
# 2   39009800
# 3   32088000
# 4   28598000

# %%
# now get the stock close price
# astype means "Copy of the array, cast to a specified type."
stock_prices = stock.Close.values.astype("float32")
shape0=stock_prices.shape[0]
stock_prices = stock_prices.reshape(shape0, 1)
print(stock_prices.shape)
# print the prices of last five observations
print(stock_prices[-5:])
# Out:
# (905, 1)
# [[ 182.67999268]
#  [ 181.38999939]
#  [ 179.11000061]
#  [ 175.57000732]
#  [ 173.08999634]]

# %%
# Before doing any analysis, first plot the prices series(data)
pyplot.plot(stock_prices)
pyplot.title('Stock close price over time')
pyplot.ylabel('Price')
pyplot.xlabel('Time Range')
pyplot.show()

# %%
values = stock_prices

# %%
# check the last five observations to make sure it's correct
print(values[-5:, :])
# Out:
# [[ 182.67999268]
#  [ 181.38999939]
#  [ 179.11000061]
#  [ 175.57000732]
#  [ 173.08999634]]

# %%
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
print(reframed.head())
# var1 means prices
# Out:
#    var1(t-1)   var1(t)
# 1   0.246905  0.219847
# 2   0.219847  0.201448
# 3   0.201448  0.224447
# 4   0.224447  0.213286
# 5   0.213286  0.223703

# %%
# split into train and test sets
values = reframed.values
n_train = int(reframed.shape[0] * 0.8)
train = values[:n_train, :]
test = values[n_train:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (723, 1, 1) (723,) (181, 1, 1) (181,)

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=300, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Train on 723 samples, validate on 181 samples
# Epoch 1/300
# 0s - loss: 0.2142 - val_loss: 0.7505
# Epoch 2/300
# 0s - loss: 0.1726 - val_loss: 0.6857
# Epoch 3/300
# 0s - loss: 0.1325 - val_loss: 0.6188
# Epoch 4/300
# 0s - loss: 0.0986 - val_loss: 0.5529
# Epoch 5/300
# 0s - loss: 0.0813 - val_loss: 0.5011
# Epoch 6/300
# 0s - loss: 0.0788 - val_loss: 0.4702
# Epoch 7/300
# 0s - loss: 0.0789 - val_loss: 0.4515
# Epoch 8/300
# 0s - loss: 0.0781 - val_loss: 0.4382
# Epoch 9/300
# 0s - loss: 0.0767 - val_loss: 0.4270
# Epoch 10/300
# 0s - loss: 0.0751 - val_loss: 0.4163
# Epoch 11/300
# 0s - loss: 0.0734 - val_loss: 0.4058
# Epoch 12/300
# 0s - loss: 0.0717 - val_loss: 0.3950
# Epoch 13/300
# 0s - loss: 0.0699 - val_loss: 0.3840
# Epoch 14/300
# 0s - loss: 0.0681 - val_loss: 0.3725
# Epoch 15/300
# 0s - loss: 0.0664 - val_loss: 0.3608
# Epoch 16/300
# 0s - loss: 0.0646 - val_loss: 0.3485
# Epoch 17/300
# 0s - loss: 0.0628 - val_loss: 0.3359
# Epoch 18/300
# 0s - loss: 0.0609 - val_loss: 0.3229
# Epoch 19/300
# 0s - loss: 0.0590 - val_loss: 0.3095
# Epoch 20/300
# 0s - loss: 0.0571 - val_loss: 0.2959
# Epoch 21/300
# 0s - loss: 0.0552 - val_loss: 0.2823
# Epoch 22/300
# 0s - loss: 0.0531 - val_loss: 0.2688
# Epoch 23/300
# 0s - loss: 0.0510 - val_loss: 0.2552
# Epoch 24/300
# 0s - loss: 0.0487 - val_loss: 0.2411
# Epoch 25/300
# 0s - loss: 0.0464 - val_loss: 0.2263
# Epoch 26/300
# 0s - loss: 0.0440 - val_loss: 0.2104
# Epoch 27/300
# 0s - loss: 0.0416 - val_loss: 0.1937
# Epoch 28/300
# 0s - loss: 0.0392 - val_loss: 0.1766
# Epoch 29/300
# 0s - loss: 0.0367 - val_loss: 0.1593
# Epoch 30/300
# 0s - loss: 0.0340 - val_loss: 0.1419
# Epoch 31/300
# 0s - loss: 0.0313 - val_loss: 0.1238
# Epoch 32/300
# 0s - loss: 0.0284 - val_loss: 0.1052
# Epoch 33/300
# 0s - loss: 0.0254 - val_loss: 0.0854
# Epoch 34/300
# 0s - loss: 0.0225 - val_loss: 0.0659
# Epoch 35/300
# 0s - loss: 0.0194 - val_loss: 0.0461
# Epoch 36/300
# 0s - loss: 0.0164 - val_loss: 0.0285
# Epoch 37/300
# 0s - loss: 0.0137 - val_loss: 0.0207
# Epoch 38/300
# 0s - loss: 0.0114 - val_loss: 0.0221
# Epoch 39/300
# 0s - loss: 0.0100 - val_loss: 0.0279
# Epoch 40/300
# 0s - loss: 0.0094 - val_loss: 0.0312
# Epoch 41/300
# 0s - loss: 0.0093 - val_loss: 0.0316
# Epoch 42/300
# 0s - loss: 0.0096 - val_loss: 0.0299
# Epoch 43/300
# 0s - loss: 0.0095 - val_loss: 0.0298
# Epoch 44/300
# 0s - loss: 0.0094 - val_loss: 0.0300
# Epoch 45/300
# 0s - loss: 0.0094 - val_loss: 0.0300
# Epoch 46/300
# 0s - loss: 0.0093 - val_loss: 0.0304
# Epoch 47/300
# 0s - loss: 0.0093 - val_loss: 0.0306
# Epoch 48/300
# 0s - loss: 0.0093 - val_loss: 0.0309
# Epoch 49/300
# 0s - loss: 0.0093 - val_loss: 0.0308
# Epoch 50/300
# 0s - loss: 0.0093 - val_loss: 0.0297
# Epoch 51/300
# 0s - loss: 0.0096 - val_loss: 0.0279
# Epoch 52/300
# 0s - loss: 0.0095 - val_loss: 0.0278
# Epoch 53/300
# 0s - loss: 0.0094 - val_loss: 0.0285
# Epoch 54/300
# 0s - loss: 0.0094 - val_loss: 0.0286
# Epoch 55/300
# 0s - loss: 0.0093 - val_loss: 0.0298
# Epoch 56/300
# 0s - loss: 0.0093 - val_loss: 0.0293
# Epoch 57/300
# 0s - loss: 0.0093 - val_loss: 0.0300
# Epoch 58/300
# 0s - loss: 0.0093 - val_loss: 0.0297
# Epoch 59/300
# 0s - loss: 0.0092 - val_loss: 0.0300
# Epoch 60/300
# 0s - loss: 0.0092 - val_loss: 0.0298
# Epoch 61/300
# 0s - loss: 0.0092 - val_loss: 0.0297
# Epoch 62/300
# 0s - loss: 0.0092 - val_loss: 0.0294
# Epoch 63/300
# 0s - loss: 0.0092 - val_loss: 0.0293
# Epoch 64/300
# 0s - loss: 0.0092 - val_loss: 0.0290
# Epoch 65/300
# 0s - loss: 0.0092 - val_loss: 0.0289
# Epoch 66/300
# 0s - loss: 0.0092 - val_loss: 0.0288
# Epoch 67/300
# 0s - loss: 0.0093 - val_loss: 0.0285
# Epoch 68/300
# 0s - loss: 0.0092 - val_loss: 0.0285
# Epoch 69/300
# 0s - loss: 0.0092 - val_loss: 0.0285
# Epoch 70/300
# 0s - loss: 0.0093 - val_loss: 0.0283
# Epoch 71/300
# 0s - loss: 0.0092 - val_loss: 0.0281
# Epoch 72/300
# 0s - loss: 0.0092 - val_loss: 0.0282
# Epoch 73/300
# 0s - loss: 0.0093 - val_loss: 0.0277
# Epoch 74/300
# 0s - loss: 0.0092 - val_loss: 0.0280
# Epoch 75/300
# 0s - loss: 0.0093 - val_loss: 0.0274
# Epoch 76/300
# 0s - loss: 0.0092 - val_loss: 0.0278
# Epoch 77/300
# 0s - loss: 0.0093 - val_loss: 0.0273
# Epoch 78/300
# 0s - loss: 0.0092 - val_loss: 0.0274
# Epoch 79/300
# 0s - loss: 0.0092 - val_loss: 0.0272
# Epoch 80/300
# 0s - loss: 0.0092 - val_loss: 0.0271
# Epoch 81/300
# 0s - loss: 0.0092 - val_loss: 0.0268
# Epoch 82/300
# 0s - loss: 0.0092 - val_loss: 0.0268
# Epoch 83/300
# 0s - loss: 0.0092 - val_loss: 0.0267
# Epoch 84/300
# 0s - loss: 0.0092 - val_loss: 0.0265
# Epoch 85/300
# 0s - loss: 0.0092 - val_loss: 0.0266
# Epoch 86/300
# 0s - loss: 0.0092 - val_loss: 0.0264
# Epoch 87/300
# 0s - loss: 0.0092 - val_loss: 0.0263
# Epoch 88/300
# 0s - loss: 0.0092 - val_loss: 0.0262
# Epoch 89/300
# 0s - loss: 0.0092 - val_loss: 0.0261
# Epoch 90/300
# 0s - loss: 0.0092 - val_loss: 0.0261
# Epoch 91/300
# 0s - loss: 0.0092 - val_loss: 0.0259
# Epoch 92/300
# 0s - loss: 0.0092 - val_loss: 0.0258
# Epoch 93/300
# 0s - loss: 0.0092 - val_loss: 0.0256
# Epoch 94/300
# 0s - loss: 0.0091 - val_loss: 0.0256
# Epoch 95/300
# 0s - loss: 0.0092 - val_loss: 0.0253
# Epoch 96/300
# 0s - loss: 0.0091 - val_loss: 0.0255
# Epoch 97/300
# 0s - loss: 0.0092 - val_loss: 0.0253
# Epoch 98/300
# 0s - loss: 0.0091 - val_loss: 0.0252
# Epoch 99/300
# 0s - loss: 0.0091 - val_loss: 0.0250
# Epoch 100/300
# 0s - loss: 0.0092 - val_loss: 0.0250
# Epoch 101/300
# 0s - loss: 0.0091 - val_loss: 0.0251
# Epoch 102/300
# 0s - loss: 0.0091 - val_loss: 0.0249
# Epoch 103/300
# 0s - loss: 0.0091 - val_loss: 0.0247
# Epoch 104/300
# 0s - loss: 0.0091 - val_loss: 0.0245
# Epoch 105/300
# 0s - loss: 0.0091 - val_loss: 0.0245
# Epoch 106/300
# 0s - loss: 0.0091 - val_loss: 0.0245
# Epoch 107/300
# 0s - loss: 0.0091 - val_loss: 0.0244
# Epoch 108/300
# 0s - loss: 0.0091 - val_loss: 0.0242
# Epoch 109/300
# 0s - loss: 0.0091 - val_loss: 0.0241
# Epoch 110/300
# 0s - loss: 0.0091 - val_loss: 0.0242
# Epoch 111/300
# 0s - loss: 0.0091 - val_loss: 0.0241
# Epoch 112/300
# 0s - loss: 0.0091 - val_loss: 0.0240
# Epoch 113/300
# 0s - loss: 0.0091 - val_loss: 0.0238
# Epoch 114/300
# 0s - loss: 0.0091 - val_loss: 0.0240
# Epoch 115/300
# 0s - loss: 0.0091 - val_loss: 0.0238
# Epoch 116/300
# 0s - loss: 0.0090 - val_loss: 0.0237
# Epoch 117/300
# 0s - loss: 0.0091 - val_loss: 0.0233
# Epoch 118/300
# 0s - loss: 0.0091 - val_loss: 0.0232
# Epoch 119/300
# 0s - loss: 0.0091 - val_loss: 0.0232
# Epoch 120/300
# 0s - loss: 0.0091 - val_loss: 0.0231
# Epoch 121/300
# 0s - loss: 0.0090 - val_loss: 0.0232
# Epoch 122/300
# 0s - loss: 0.0091 - val_loss: 0.0230
# Epoch 123/300
# 0s - loss: 0.0090 - val_loss: 0.0230
# Epoch 124/300
# 0s - loss: 0.0091 - val_loss: 0.0227
# Epoch 125/300
# 0s - loss: 0.0090 - val_loss: 0.0228
# Epoch 126/300
# 0s - loss: 0.0090 - val_loss: 0.0226
# Epoch 127/300
# 0s - loss: 0.0090 - val_loss: 0.0225
# Epoch 128/300
# 0s - loss: 0.0090 - val_loss: 0.0224
# Epoch 129/300
# 0s - loss: 0.0091 - val_loss: 0.0223
# Epoch 130/300
# 0s - loss: 0.0090 - val_loss: 0.0223
# Epoch 131/300
# 0s - loss: 0.0089 - val_loss: 0.0223
# Epoch 132/300
# 0s - loss: 0.0090 - val_loss: 0.0222
# Epoch 133/300
# 0s - loss: 0.0091 - val_loss: 0.0220
# Epoch 134/300
# 0s - loss: 0.0090 - val_loss: 0.0221
# Epoch 135/300
# 0s - loss: 0.0090 - val_loss: 0.0220
# Epoch 136/300
# 0s - loss: 0.0090 - val_loss: 0.0218
# Epoch 137/300
# 0s - loss: 0.0091 - val_loss: 0.0217
# Epoch 138/300
# 0s - loss: 0.0090 - val_loss: 0.0217
# Epoch 139/300
# 0s - loss: 0.0089 - val_loss: 0.0218
# Epoch 140/300
# 0s - loss: 0.0091 - val_loss: 0.0214
# Epoch 141/300
# 0s - loss: 0.0089 - val_loss: 0.0215
# Epoch 142/300
# 0s - loss: 0.0090 - val_loss: 0.0215
# Epoch 143/300
# 0s - loss: 0.0091 - val_loss: 0.0211
# Epoch 144/300
# 0s - loss: 0.0089 - val_loss: 0.0214
# Epoch 145/300
# 0s - loss: 0.0090 - val_loss: 0.0213
# Epoch 146/300
# 0s - loss: 0.0090 - val_loss: 0.0211
# Epoch 147/300
# 0s - loss: 0.0089 - val_loss: 0.0211
# Epoch 148/300
# 0s - loss: 0.0090 - val_loss: 0.0210
# Epoch 149/300
# 0s - loss: 0.0090 - val_loss: 0.0209
# Epoch 150/300
# 0s - loss: 0.0090 - val_loss: 0.0208
# Epoch 151/300
# 0s - loss: 0.0090 - val_loss: 0.0207
# Epoch 152/300
# 0s - loss: 0.0090 - val_loss: 0.0207
# Epoch 153/300
# 0s - loss: 0.0090 - val_loss: 0.0206
# Epoch 154/300
# 0s - loss: 0.0089 - val_loss: 0.0206
# Epoch 155/300
# 0s - loss: 0.0090 - val_loss: 0.0205
# Epoch 156/300
# 0s - loss: 0.0090 - val_loss: 0.0205
# Epoch 157/300
# 0s - loss: 0.0090 - val_loss: 0.0205
# Epoch 158/300
# 0s - loss: 0.0089 - val_loss: 0.0205
# Epoch 159/300
# 0s - loss: 0.0090 - val_loss: 0.0204
# Epoch 160/300
# 0s - loss: 0.0089 - val_loss: 0.0204
# Epoch 161/300
# 0s - loss: 0.0089 - val_loss: 0.0203
# Epoch 162/300
# 0s - loss: 0.0089 - val_loss: 0.0202
# Epoch 163/300
# 0s - loss: 0.0090 - val_loss: 0.0201
# Epoch 164/300
# 0s - loss: 0.0089 - val_loss: 0.0201
# Epoch 165/300
# 0s - loss: 0.0089 - val_loss: 0.0201
# Epoch 166/300
# 0s - loss: 0.0089 - val_loss: 0.0200
# Epoch 167/300
# 0s - loss: 0.0089 - val_loss: 0.0200
# Epoch 168/300
# 0s - loss: 0.0089 - val_loss: 0.0199
# Epoch 169/300
# 0s - loss: 0.0089 - val_loss: 0.0199
# Epoch 170/300
# 0s - loss: 0.0090 - val_loss: 0.0198
# Epoch 171/300
# 0s - loss: 0.0089 - val_loss: 0.0198
# Epoch 172/300
# 0s - loss: 0.0089 - val_loss: 0.0198
# Epoch 173/300
# 0s - loss: 0.0089 - val_loss: 0.0197
# Epoch 174/300
# 0s - loss: 0.0089 - val_loss: 0.0197
# Epoch 175/300
# 0s - loss: 0.0089 - val_loss: 0.0197
# Epoch 176/300
# 0s - loss: 0.0089 - val_loss: 0.0196
# Epoch 177/300
# 0s - loss: 0.0089 - val_loss: 0.0196
# Epoch 178/300
# 0s - loss: 0.0089 - val_loss: 0.0196
# Epoch 179/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 180/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 181/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 182/300
# 0s - loss: 0.0090 - val_loss: 0.0195
# Epoch 183/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 184/300
# 0s - loss: 0.0090 - val_loss: 0.0195
# Epoch 185/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 186/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 187/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 188/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 189/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 190/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 191/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 192/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 193/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 194/300
# 0s - loss: 0.0090 - val_loss: 0.0194
# Epoch 195/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 196/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 197/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 198/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 199/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 200/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 201/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 202/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 203/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 204/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 205/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 206/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 207/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 208/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 209/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 210/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 211/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 212/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 213/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 214/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 215/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 216/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 217/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 218/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 219/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 220/300
# 0s - loss: 0.0089 - val_loss: 0.0194
# Epoch 221/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 222/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 223/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 224/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 225/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 226/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 227/300
# 0s - loss: 0.0089 - val_loss: 0.0195
# Epoch 228/300
# 0s - loss: 0.0089 - val_loss: 0.0196
# Epoch 229/300
# 0s - loss: 0.0089 - val_loss: 0.0192
# Epoch 230/300
# 0s - loss: 0.0093 - val_loss: 0.0197
# Epoch 231/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 232/300
# 0s - loss: 0.0090 - val_loss: 0.0194
# Epoch 233/300
# 0s - loss: 0.0102 - val_loss: 0.0208
# Epoch 234/300
# 0s - loss: 0.0093 - val_loss: 0.0199
# Epoch 235/300
# 0s - loss: 0.0092 - val_loss: 0.0192
# Epoch 236/300
# 0s - loss: 0.0090 - val_loss: 0.0192
# Epoch 237/300
# 0s - loss: 0.0106 - val_loss: 0.0207
# Epoch 238/300
# 0s - loss: 0.0091 - val_loss: 0.0193
# Epoch 239/300
# 0s - loss: 0.0092 - val_loss: 0.0192
# Epoch 240/300
# 0s - loss: 0.0094 - val_loss: 0.0197
# Epoch 241/300
# 0s - loss: 0.0104 - val_loss: 0.0207
# Epoch 242/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 243/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 244/300
# 0s - loss: 0.0093 - val_loss: 0.0198
# Epoch 245/300
# 0s - loss: 0.0102 - val_loss: 0.0205
# Epoch 246/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 247/300
# 0s - loss: 0.0092 - val_loss: 0.0192
# Epoch 248/300
# 0s - loss: 0.0094 - val_loss: 0.0198
# Epoch 249/300
# 0s - loss: 0.0104 - val_loss: 0.0207
# Epoch 250/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 251/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 252/300
# 0s - loss: 0.0093 - val_loss: 0.0198
# Epoch 253/300
# 0s - loss: 0.0102 - val_loss: 0.0206
# Epoch 254/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 255/300
# 0s - loss: 0.0092 - val_loss: 0.0192
# Epoch 256/300
# 0s - loss: 0.0094 - val_loss: 0.0198
# Epoch 257/300
# 0s - loss: 0.0102 - val_loss: 0.0206
# Epoch 258/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 259/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 260/300
# 0s - loss: 0.0094 - val_loss: 0.0198
# Epoch 261/300
# 0s - loss: 0.0102 - val_loss: 0.0206
# Epoch 262/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 263/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 264/300
# 0s - loss: 0.0094 - val_loss: 0.0198
# Epoch 265/300
# 0s - loss: 0.0102 - val_loss: 0.0204
# Epoch 266/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 267/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 268/300
# 0s - loss: 0.0093 - val_loss: 0.0198
# Epoch 269/300
# 0s - loss: 0.0101 - val_loss: 0.0204
# Epoch 270/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 271/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 272/300
# 0s - loss: 0.0093 - val_loss: 0.0198
# Epoch 273/300
# 0s - loss: 0.0101 - val_loss: 0.0204
# Epoch 274/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 275/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 276/300
# 0s - loss: 0.0093 - val_loss: 0.0197
# Epoch 277/300
# 0s - loss: 0.0101 - val_loss: 0.0205
# Epoch 278/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 279/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 280/300
# 0s - loss: 0.0093 - val_loss: 0.0198
# Epoch 281/300
# 0s - loss: 0.0100 - val_loss: 0.0203
# Epoch 282/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 283/300
# 0s - loss: 0.0092 - val_loss: 0.0192
# Epoch 284/300
# 0s - loss: 0.0094 - val_loss: 0.0198
# Epoch 285/300
# 0s - loss: 0.0102 - val_loss: 0.0204
# Epoch 286/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 287/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 288/300
# 0s - loss: 0.0093 - val_loss: 0.0197
# Epoch 289/300
# 0s - loss: 0.0100 - val_loss: 0.0201
# Epoch 290/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 291/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 292/300
# 0s - loss: 0.0092 - val_loss: 0.0198
# Epoch 293/300
# 0s - loss: 0.0101 - val_loss: 0.0206
# Epoch 294/300
# 0s - loss: 0.0089 - val_loss: 0.0193
# Epoch 295/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 296/300
# 0s - loss: 0.0094 - val_loss: 0.0198
# Epoch 297/300
# 0s - loss: 0.0101 - val_loss: 0.0203
# Epoch 298/300
# 0s - loss: 0.0090 - val_loss: 0.0193
# Epoch 299/300
# 0s - loss: 0.0091 - val_loss: 0.0192
# Epoch 300/300
# 0s - loss: 0.0093 - val_loss: 0.0198

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
# make a prediction for train data
yhat_train = model.predict(train_X)
train_X = train_X.reshape((train_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat_train = concatenate((yhat_train, train_X[:, 1:]), axis=1)
inv_yhat_train = scaler.inverse_transform(inv_yhat_train)
inv_yhat_train = inv_yhat_train[:,0]
# invert scaling for actual
train_y = train_y.reshape((len(train_y), 1))
inv_y_train = concatenate((train_y, train_X[:, 1:]), axis=1)
inv_y_train = scaler.inverse_transform(inv_y_train)
inv_y_train = inv_y_train[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y_train, inv_yhat_train))
print('Train RMSE: %.3f' % rmse)
# Out:
# Train RMSE: 1.878

# %%
# plot only the train data and predicted train data
trainline, =pyplot.plot(inv_y_train, label='train data')  # blue one
trainPredictline, =pyplot.plot(inv_yhat_train, label='predicted train data') # orange one
pyplot.title("Train data perormance")
pyplot.ylabel('Stock price')
pyplot.xlabel('Time range')
pyplot.legend(handles=[trainline, trainPredictline])
pyplot.show()

# %%
# plot only the last 100 train data and predicted train data
trainline, =pyplot.plot(inv_y_train[-30:], label='train data')  # blue one
trainPredictline, =pyplot.plot(inv_yhat_train[-30:], label='predicted train data') # orange one
pyplot.title("Train data perormance over recent 30 observations")
pyplot.ylabel('Stock price')
pyplot.xlabel('Time range')
pyplot.legend(handles=[trainline, trainPredictline])
pyplot.show()

# %%
# check some observations of train data
print(inv_y_train.shape)
print(inv_yhat_train.shape)
# check the performance
print(inv_y_train[-1])
print(inv_yhat_train[-1])
#
print(inv_y_train[-2])
print(inv_yhat_train[-2])
#
print(inv_y_train[-3])
print(inv_yhat_train[-3])
#
print(inv_y_train[-4])
print(inv_yhat_train[-4])
# Out:
# (723,)
# (723,)
# 153.32
# 151.819
# 151.91
# 154.587
# 154.73
# 154.802
# 154.95
# 157.36

# %%
# plot the difference for train data
traindiff = inv_yhat_train - inv_y_train
#
maxtraindiff=abs(max(traindiff, key=abs))
print('The largest absolute difference for train data: %.2f' % (maxtraindiff))
#
pyplot.plot(traindiff)
#
pyplot.title("Predicted train data minus train data")
pyplot.ylabel('Difference')
pyplot.xlabel('Time range')
pyplot.show()
# Out:
# The largest absolute difference for train data: 16.45

# %%
# plot the difference for the recent 30 obs of train data
pyplot.plot(traindiff[-30:])
#
pyplot.title("Predicted train data minus train data over recent 30 observations")
pyplot.ylabel('Difference')
pyplot.xlabel('Time range')
pyplot.show()

# %%
# make a prediction for test data
yhat_test = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat_test = concatenate((yhat_test, test_X[:, 1:]), axis=1)
inv_yhat_test = scaler.inverse_transform(inv_yhat_test)
inv_yhat_test = inv_yhat_test[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y_test = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y_test = scaler.inverse_transform(inv_y_test)
inv_y_test = inv_y_test[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y_test, inv_yhat_test))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 3.727

# %%
# plot only the test data and predicted test data
testline, =pyplot.plot(inv_y_test, label='test data')  # blue one
testPredictline, =pyplot.plot(inv_yhat_test, label='predicted test data') # orange one
pyplot.title("Test data perormance")
pyplot.ylabel('Stock price')
pyplot.xlabel('Time range')
pyplot.legend(handles=[testline, testPredictline])
pyplot.show()

# %%
# plot only the last 30 test data and predicted test data
testline, =pyplot.plot(inv_y_test[-30:], label='test data')  # blue one
testPredictline, =pyplot.plot(inv_yhat_test[-30:], label='predicted test data') # orange one
pyplot.title("Test data perormance over recent 30 observations")
pyplot.ylabel('Stock price')
pyplot.xlabel('Time range')
pyplot.legend(handles=[testline, testPredictline])
pyplot.show()

# %%
# check some observations of test data
print(inv_y_test.shape)
print(inv_yhat_test.shape)
# check the performance
print(inv_y_test[-1])
print(inv_yhat_test[-1])
#
print(inv_y_test[-2])
print(inv_yhat_test[-2])
#
print(inv_y_test[-3])
print(inv_yhat_test[-3])
#
print(inv_y_test[-4])
print(inv_yhat_test[-4])
# Out:
# (181,)
# (181,)
# 173.09
# 174.907
# 175.57
# 178.332
# 179.11
# 180.533
# 181.39
# 181.777

# %%
# plot the difference for test data
testdiff = inv_yhat_test - inv_y_test
#
maxtestdiff=abs(max(testdiff, key=abs))
print('The largest absolute difference for test data: %.2f' % (maxtestdiff))
#
pyplot.plot(testdiff)
#
pyplot.title("Predicted test data minus test data")
pyplot.ylabel('Difference')
pyplot.xlabel('Time range')
pyplot.show()
# Out:
# The largest absolute difference for test data: 11.79

# %%
# plot the difference for the recent 30 obs of test data
pyplot.plot(testdiff[-30:])
#
pyplot.title("Predicted test data minus test data over recent 30 observations")
pyplot.ylabel('Difference')
pyplot.xlabel('Time range')
pyplot.show()
